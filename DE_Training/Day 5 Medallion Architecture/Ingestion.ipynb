# %%
# %run "/Workspace/Users/sheetalyadav1041@gmail.com/DE_Training/Day 5 Medallion Architecture/Include"

# %%
file_name = "Customers"
schema = "Bronze"
catalog = "dev" 
table_name = "Customers"

# %%
df = spark.read.csv(f"{input_path}{file_name}", header=True, inferSchema=True)

# %%
df1 = add_ingestion_col(df)

# %%
df1.write.mode("overwrite").saveAsTable(f"{catalog}.{schema}.{table_name}")
